# %%
import sys
sys.path.append('..')
from src.mediapipe_portion.landmarks import video_to_parquet

# %%
shape = video_to_parquet(video_path='/home/jbsb/Desktop/Projects/isolated_Sign_language_translator/src/mediapipe_portion/book.mp4',parquet_path='book_test.parquet')

print(shape)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1780118791.916903  122459 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1780118791.930194  122587 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 26.0.6-arch1.1), renderer: AMD Radeon Graphics (radeonsi, renoir, ACO, DRM 3.64, 7.0.7-arch2-1)
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# (77, 118, 3)

# %%
import pandas as pd
filepath='/home/jbsb/Desktop/Projects/isolated_Sign_language_translator/notebooks/book_test.parquet'
df= pd.read_parquet(filepath)
df.head()
# Out:
#           x         y         z
# 0  0.511267  0.283409 -0.015418
# 1  0.482781  0.291188  0.004424
# 2  0.484777  0.289072 -0.000979
# 3  0.489132  0.287133 -0.006392
# 4  0.494771  0.284307 -0.011262
